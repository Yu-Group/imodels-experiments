# %%
import openml
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings(action='ignore', category=FutureWarning,
                        module='openml')

# %%
from subgroup import get_openml_data

# %%
get_openml_data(361234)
# Out:
# /tmp/ipykernel_1628920/4046681467.py:1: FutureWarning: Starting from Version 0.15.0 `download_splits` will default to ``False`` instead of ``True`` and be independent from `download_data`. To disable this message until version 0.15 explicitly set `download_splits` to a bool.
#   get_openml_data(361234)
# (array([['M', 0.455, 0.365, ..., 0.2245, 0.101, 0.15],
#         ['M', 0.35, 0.265, ..., 0.0995, 0.0485, 0.07],
#         ['F', 0.53, 0.42, ..., 0.2565, 0.1415, 0.21],
#         ...,
#         ['M', 0.6, 0.475, ..., 0.5255, 0.2875, 0.308],
#         ['F', 0.625, 0.485, ..., 0.531, 0.261, 0.296],
#         ['M', 0.71, 0.555, ..., 0.9455, 0.3765, 0.495]], dtype=object),
#  array([15.,  7.,  9., ...,  9., 10., 12.]))

# %%
dataids = [361234, 361235, 361236, 361237, 361241, 361242, 361243, 361244,
           361247, 361249, 361250, 361251, 361252, 361253, 361254, 361255,
           361256, 361257, 361258, 361259, 361260, 361261, 361264, 361266,
           361267, 361268, 361269, 361272, 361616, 361617, 361618, 361619,
           361621, 361622, 361623]

# %%
# get version of openml package downloaded
print(openml.__version__)
# Out:
# 0.14.2

# %%
task = openml.tasks.get_task(dataids[0], download_splits=False, download_data=False, download_features_meta_data=False, download_qualities=False)
dataset = task.get_dataset()
X, y, _, _ = dataset.get_data(target=dataset.default_target_attribute)

# %%
import pandas as pd

# %%
pd.get_dummies(X)
# Out:
#       length  diameter  height  whole_weight  shucked_weight  cisvera_weight  \
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# ...      ...       ...     ...           ...             ...             ...
# 4172   0.565     0.450   0.165        0.8870          0.3700          0.2390
# 4173   0.590     0.440   0.135        0.9660          0.4390          0.2145
# 4174   0.600     0.475   0.205        1.1760          0.5255          0.2875
# 4175   0.625     0.485   0.150        1.0945          0.5310          0.2610
# 4176   0.710     0.555   0.195        1.9485          0.9455          0.3765
#
#       shell_weight  sex_F  sex_I  sex_M
# 0           0.1500  False  False   True
# 1           0.0700  False  False   True
# 2           0.2100   True  False  False
# 3           0.1550  False  False   True
# 4           0.0550  False   True  False
# ...            ...    ...    ...    ...
# 4172        0.2490   True  False  False
# 4173        0.2605  False  False   True
# 4174        0.3080  False  False   True
# 4175        0.2960   True  False  False
# 4176        0.4950  False  False   True
#
# [4177 rows x 10 columns]

# %%
# get the dataset from openml
for id in dataids:
    task = openml.tasks.get_task(id, download_splits=False, download_data=False,
                                 download_features_meta_data=False,
                                 download_qualities=False)
    dataset = task.get_dataset()
    X, y, _, _ = dataset.get_data(target=dataset.default_target_attribute)
    print('Dataset ID:', id)
    # print('Dataset Name:', dataset.name)
    # print('Number of Features:', X.shape[1])
    # print('Number of Instances:', X.shape[0])
    # print('Type of Target Values:')
    print(y.dtype)
    # do they have a column that is non-numeric?
    print(X.dtypes)
    # plt.hist(y, bins=20)
    # plt.show()
    print('-----------------------------------')
# Out:
# Dataset ID: 361234
# uint8
# sex               category
# length             float64
# diameter           float64
# height             float64
# whole_weight       float64
# shucked_weight     float64
# cisvera_weight     float64
# shell_weight       float64
# dtype: object
# -----------------------------------
# Dataset ID: 361235
# float64
# frequency                 float64
# angle_of_attack           float64
# chord_length              float64
# free_stream_velocity      float64
# displacement_thickness    float64
# dtype: object
# -----------------------------------
# Dataset ID: 361236
# float64
# process.b1.capacity       uint8
# process.b2.capacity       uint8
# process.b3.capacity       uint8
# process.b4.capacity       uint8
# property.price            uint8
# property.product       category
# property.winner        category
# dtype: object
# -----------------------------------
# Dataset ID: 361237
# float64
# cement                float64
# blast_furnace_slag    float64
# fly_ash               float64
# water                 float64
# superplasticizer      float64
# coarse_aggregate      float64
# fine_aggregate        float64
# age                   float64
# dtype: object
# -----------------------------------
# Dataset ID: 361241
# float64
# F1    float64
# F2    float64
# F3    float64
# F4    float64
# F5    float64
# F6    float64
# F7    float64
# F8    float64
# F9    float64
# dtype: object
# -----------------------------------
# Dataset ID: 361242
# float64
# number_of_elements         uint8
# mean_atomic_mass         float64
# wtd_mean_atomic_mass     float64
# gmean_atomic_mass        float64
# wtd_gmean_atomic_mass    float64
#                           ...
# wtd_entropy_Valence      float64
# range_Valence              uint8
# wtd_range_Valence        float64
# std_Valence              float64
# wtd_std_Valence          float64
# Length: 81, dtype: object
# -----------------------------------
# Dataset ID: 361243
# float64
# V1      float64
# V2      float64
# V3      float64
# V4      float64
# V5      float64
#          ...
# V112    float64
# V113    float64
# V114    float64
# V115    float64
# V116    float64
# Length: 116, dtype: object
# -----------------------------------
# Dataset ID: 361244
# uint8
# class                category
# largest_spot_size    category
# spot_distribution    category
# activity             category
# evolution               uint8
# previous_activity    category
# complex              category
# complex_path         category
# area                 category
# area_largest            uint8
# dtype: object
# -----------------------------------
# Dataset ID: 361247
# float64
# lever_position                          float64
# ship_speed                                uint8
# gas_turbine_shaft_torque                float64
# gas_turbine_rate_of_revolutions         float64
# gas_generator_rate_of_revolutions       float64
# starboard_propeller_torque              float64
# port_propeller_torque                   float64
# hp_turbine_exit_temperature             float64
# gt_compressor_outlet_air_temperature    float64
# hp_turbine_exit_pressure                float64
# gt_compressor_outlet_air_pressure       float64
# gas_turbine_exhaust_gas_pressure        float64
# turbine_injecton_control                float64
# fuel_flow                               float64
# dtype: object
# -----------------------------------
# Dataset ID: 361249
# uint8
# fixed_acidity           float64
# volatile_acidity        float64
# citric_acid             float64
# residual_sugar          float64
# chlorides               float64
# free_sulfur_dioxide     float64
# total_sulfur_dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# dtype: object
# -----------------------------------
# Dataset ID: 361250
# uint8
# fixed_acidity           float64
# volatile_acidity        float64
# citric_acid             float64
# residual_sugar          float64
# chlorides               float64
# free_sulfur_dioxide     float64
# total_sulfur_dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# dtype: object
# -----------------------------------
# Dataset ID: 361251
# float64
# tau1    float64
# tau2    float64
# tau3    float64
# tau4    float64
# p1      float64
# p2      float64
# p3      float64
# p4      float64
# g1      float64
# g2      float64
# g3      float64
# g4      float64
# dtype: object
# -----------------------------------
# Dataset ID: 361252
# float64
# duration        float64
# codec          category
# width           float64
# height          float64
# bitrate         float64
# framerate       float64
# i               float64
# p               float64
# b               float64
# frames          float64
# i_size          float64
# p_size          float64
# size            float64
# o_codec        category
# o_bitrate       float64
# o_framerate     float64
# o_width         float64
# o_height        float64
# dtype: object
# -----------------------------------
# Dataset ID: 361253
# float64
# x1          float64
# x2          float64
# x3          float64
# x4          float64
# x5          float64
# x6          float64
# x7          float64
# x8          float64
# x9          float64
# x10         float64
# x11         float64
# x12         float64
# x13         float64
# x14         float64
# x15         float64
# x16         float64
# y1          float64
# y2          float64
# y3          float64
# y4          float64
# y5          float64
# y6          float64
# y7          float64
# y8          float64
# y9          float64
# y10         float64
# y11         float64
# y12         float64
# y13         float64
# y14         float64
# y15         float64
# y16         float64
# energy1     float64
# energy2     float64
# energy3     float64
# energy4     float64
# energy5     float64
# energy6     float64
# energy7     float64
# energy8     float64
# energy9     float64
# energy10    float64
# energy11    float64
# energy12    float64
# energy13    float64
# energy14    float64
# energy15    float64
# energy16    float64
# dtype: object
# -----------------------------------
# Dataset ID: 361254
# float64
# V1     float64
# V2     float64
# V3     float64
# V4     float64
# V5     float64
# V6     float64
# V7     float64
# V8     float64
# V9     float64
# V10    float64
# V11    float64
# V12    float64
# V13    float64
# V14    float64
# V15    float64
# V16    float64
# V17    float64
# V18    float64
# V19    float64
# V20    float64
# V21    float64
# dtype: object
# -----------------------------------
# Dataset ID: 361255
# float64
# longitude           float64
# latitude            float64
# housingMedianAge      uint8
# totalRooms          float64
# totalBedrooms       float64
# population          float64
# households          float64
# medianIncome        float64
# dtype: object
# -----------------------------------
# Dataset ID: 361256
# uint8
# lread       float64
# lwrite      float64
# scall       float64
# sread       float64
# swrite      float64
# fork        float64
# exec        float64
# rchar       float64
# wchar       float64
# pgout       float64
# ppgout      float64
# pgfree      float64
# pgscan      float64
# atch        float64
# pgin        float64
# ppgin       float64
# pflt        float64
# vflt        float64
# runqsz      float64
# freemem     float64
# freeswap    float64
# dtype: object
# -----------------------------------
# Dataset ID: 361257
# float64
# carat       float64
# cut        category
# color      category
# clarity    category
# depth       float64
# table       float64
# x           float64
# y           float64
# z           float64
# dtype: object
# -----------------------------------
# Dataset ID: 361258
# float64
# theta1    float64
# theta2    float64
# theta3    float64
# theta4    float64
# theta5    float64
# theta6    float64
# theta7    float64
# theta8    float64
# dtype: object
# -----------------------------------
# Dataset ID: 361259
# float64
# theta1     float64
# theta2     float64
# theta3     float64
# theta4     float64
# theta5     float64
# theta6     float64
# thetad1    float64
# thetad2    float64
# thetad3    float64
# thetad4    float64
# thetad5    float64
# thetad6    float64
# tau1       float64
# tau2       float64
# tau3       float64
# tau4       float64
# tau5       float64
# dm1        float64
# dm2        float64
# dm3        float64
# dm4        float64
# dm5        float64
# da1        float64
# da2        float64
# da3        float64
# da4        float64
# da5        float64
# db1        float64
# db2        float64
# db3        float64
# db4        float64
# db5        float64
# dtype: object
# -----------------------------------
# Dataset ID: 361260
# float64
# LATITUDE             float64
# LONGITUDE            float64
# LND_SQFOOT           float64
# TOT_LVG_AREA         float64
# SPEC_FEAT_VAL        float64
# RAIL_DIST            float64
# OCEAN_DIST           float64
# WATER_DIST           float64
# CNTR_DIST            float64
# SUBCNTR_DI           float64
# HWY_DIST             float64
# age                    uint8
# avno60plus             uint8
# month_sold             uint8
# structure_quality      uint8
# dtype: object
# -----------------------------------
# Dataset ID: 361261
# float64
# education        uint8
# experience     float64
# ethnicity     category
# smsa          category
# region        category
# parttime      category
# dtype: object
# -----------------------------------
# Dataset ID: 361264
# float64
# fathers_occupation                  category
# sons_occupation                     category
# family_structure                    category
# race                                category
# counts_for_sons_first_occupation     float64
# dtype: object
# -----------------------------------
# Dataset ID: 361266
# float64
# bedrooms            uint8
# bathrooms         float64
# sqft_living       float64
# sqft_lot          float64
# floors            float64
# waterfront          uint8
# view                uint8
# condition           uint8
# grade               uint8
# sqft_above        float64
# sqft_basement     float64
# yr_built          float64
# yr_renovated      float64
# zipcode          category
# lat               float64
# long              float64
# sqft_living15     float64
# sqft_lot15        float64
# date_year        category
# date_month       category
# date_day         category
# dtype: object
# -----------------------------------
# Dataset ID: 361267
# float64
# city              category
# area               float64
# rooms                uint8
# bathroom             uint8
# parking_spaces       uint8
# floor             category
# animal            category
# furniture         category
# hoa                float64
# dtype: object
# -----------------------------------
# Dataset ID: 361268
# float64
# CpuName                      category
# CpuNumberOfCores                uint8
# CpuNumberOfThreads              uint8
# CpuBaseClock                    uint8
# CpuCacheL1                    float64
# CpuCacheL2                    float64
# CpuCacheL3                      uint8
# CpuDieSize                    float64
# CpuFrequency                  float64
# CpuMultiplier                   uint8
# CpuMultiplierUnlocked        category
# CpuProcessSize                  uint8
# CpuTDP                          uint8
# CpuNumberOfTransistors        float64
# CpuTurboClock                 float64
# GpuName                      category
# GpuArchitecture              category
# GpuBandwidth                  float64
# GpuBaseClock                  float64
# GpuBoostClock                 float64
# GpuBus.interface             category
# GpuNumberOfComputeUnits       float64
# GpuDieSize                    float64
# GpuDirectX                   category
# GpuNumberOfExecutionUnits      object
# GpuFP32Performance            float64
# GpuMemoryBus                  float64
# GpuMemorySize                 float64
# GpuMemoryType                category
# GpuOpenCL                    category
# GpuOpenGL                    category
# GpuPixelRate                  float64
# GpuProcessSize                  uint8
# GpuNumberOfROPs                 uint8
# GpuShaderModel               category
# GpuNumberOfShadingUnits       float64
# GpuNumberOfTMUs               float64
# GpuTextureRate                float64
# GpuNumberOfTransistors        float64
# GpuVulkan                    category
# GameName                     category
# GameResolution                float64
# GameSetting                  category
# dtype: object
# -----------------------------------
# Dataset ID: 361269
# uint8
# hhi           category
# whi           category
# hhi2          category
# education     category
# race          category
# hispanic      category
# experience     float64
# kidslt6          uint8
# kids618          uint8
# husby          float64
# region        category
# dtype: object
# -----------------------------------
# Dataset ID: 361272
# float64
# age                              uint8
# height_cm                        uint8
# weight_kg                        uint8
# nationality_name              category
# overall                          uint8
# potential                        uint8
# attacking_crossing               uint8
# attacking_finishing              uint8
# attacking_heading_accuracy       uint8
# attacking_short_passing          uint8
# attacking_volleys                uint8
# skill_dribbling                  uint8
# skill_curve                      uint8
# skill_fk_accuracy                uint8
# skill_long_passing               uint8
# skill_ball_control               uint8
# movement_acceleration            uint8
# movement_sprint_speed            uint8
# movement_agility                 uint8
# movement_reactions               uint8
# movement_balance                 uint8
# defending_standing_tackle        uint8
# defending_sliding_tackle         uint8
# goalkeeping_diving               uint8
# goalkeeping_handling             uint8
# goalkeeping_kicking              uint8
# goalkeeping_positioning          uint8
# goalkeeping_reflexes             uint8
# dtype: object
# -----------------------------------
# Dataset ID: 361616
# int64
# Team            category
# League          category
# Year               int64
# RA                 int64
# W                  uint8
# OBP              float64
# SLG              float64
# BA               float64
# Playoffs        category
# RankSeason      category
# RankPlayoffs    category
# G               category
# OOBP             float64
# OSLG             float64
# dtype: object
# -----------------------------------
# Dataset ID: 361617
# float64
# relative_compactness         float64
# surface_area                 float64
# wall_area                    float64
# roof_area                    float64
# overall_height               float64
# orientation                    uint8
# glazing_area                 float64
# glazing_area_distribution      uint8
# dtype: object
# -----------------------------------
# Dataset ID: 361618
# float64
# X          uint8
# Y          uint8
# month     object
# day       object
# FFMC     float64
# DMC      float64
# DC       float64
# ISI      float64
# temp     float64
# RH         uint8
# wind     float64
# rain     float64
# dtype: object
# -----------------------------------
# Dataset ID: 361619
# uint8
# school        category
# sex           category
# age              uint8
# address       category
# famsize       category
# Pstatus       category
# Medu             uint8
# Fedu             uint8
# Mjob          category
# Fjob          category
# reason        category
# guardian      category
# traveltime       uint8
# studytime        uint8
# failures         uint8
# schoolsup     category
# famsup        category
# paid          category
# activities    category
# nursery       category
# higher        category
# internet      category
# romantic      category
# famrel           uint8
# freetime         uint8
# goout            uint8
# Dalc             uint8
# Walc             uint8
# health           uint8
# absences         uint8
# dtype: object
# -----------------------------------
# Dataset ID: 361621
# float64
# CIC0      float64
# SM1_Dz    float64
# GATS1i    float64
# NdsCH       uint8
# NdssC       uint8
# MLOGP     float64
# dtype: object
# -----------------------------------
# Dataset ID: 361622
# float64
# Mileage        float64
# Cylinder         uint8
# Doors            uint8
# Cruise           uint8
# Sound            uint8
# Leather          uint8
# Buick            uint8
# Cadillac         uint8
# Chevy            uint8
# Pontiac          uint8
# Saab             uint8
# Saturn           uint8
# convertible      uint8
# coupe            uint8
# hatchback        uint8
# sedan            uint8
# wagon            uint8
# dtype: object
# -----------------------------------
# Dataset ID: 361623
# float64
# pop          float64
# education    float64
# houses       float64
# income       float64
# xcoord       float64
# ycoord       float64
# dtype: object
# -----------------------------------

# %%
transform_ids = [361236, 361242, 361244, 361252, 361257, 361260, 361261, 361264, 361266, 361267, 361272, 361618, 361622]

# %%
import numpy as np

# %%
for id in transform_ids:
    task = openml.tasks.get_task(id, download_splits=False, download_data=False,
                                 download_features_meta_data=False,
                                 download_qualities=False)
    dataset = task.get_dataset()
    X, y, _, _ = dataset.get_data(target=dataset.default_target_attribute)
    print('Dataset ID:', id)
    print('Dataset Name:', dataset.name)
    print('Number of Features:', X.shape[1])
    print('Number of Instances:', X.shape[0])
    print('Histogram of Target Values:')
    plt.hist(y, bins=20)
    plt.show()
    # if min value of y is greater than 0, then log transform y
    if np.min(y) > 0:
        y = np.log(y)
    if np.min(y) <= 0:
        y = np.log(y - np.min(y) + 1)
    plt.hist(y, bins=20)
    plt.show()
    print('-----------------------------------')
# Out:
# Dataset ID: 361236
# Dataset Name: auction_verification
# Number of Features: 7
# Number of Instances: 2043
# Histogram of Target Values:
# -----------------------------------
# Dataset ID: 361242
# Dataset Name: superconductivity
# Number of Features: 81
# Number of Instances: 21263
# Histogram of Target Values:
# -----------------------------------
# Dataset ID: 361244
# Dataset Name: solar_flare
# Number of Features: 10
# Number of Instances: 1066
# Histogram of Target Values:
# -----------------------------------
# Dataset ID: 361252
# Dataset Name: video_transcoding
# Number of Features: 18
# Number of Instances: 68784
# Histogram of Target Values:
# -----------------------------------
# Dataset ID: 361257
# Dataset Name: diamonds
# Number of Features: 9
# Number of Instances: 53940
# Histogram of Target Values:
# -----------------------------------
# Dataset ID: 361260
# Dataset Name: miami_housing
# Number of Features: 15
# Number of Instances: 13932
# Histogram of Target Values:
# -----------------------------------
# Dataset ID: 361261
# Dataset Name: cps88wages
# Number of Features: 6
# Number of Instances: 28155
# Histogram of Target Values:
# -----------------------------------
# Dataset ID: 361264
# Dataset Name: socmob
# Number of Features: 5
# Number of Instances: 1156
# Histogram of Target Values:
# -----------------------------------
# Dataset ID: 361266
# Dataset Name: kings_county
# Number of Features: 21
# Number of Instances: 21613
# Histogram of Target Values:
# -----------------------------------
# Dataset ID: 361267
# Dataset Name: brazilian_houses
# Number of Features: 9
# Number of Instances: 10692
# Histogram of Target Values:
# -----------------------------------
# Dataset ID: 361272
# Dataset Name: fifa
# Number of Features: 28
# Number of Instances: 19178
# Histogram of Target Values:
# -----------------------------------
# Dataset ID: 361618
# Dataset Name: forest_fires
# Number of Features: 12
# Number of Instances: 517
# Histogram of Target Values:
# -----------------------------------
# Dataset ID: 361622
# Dataset Name: cars
# Number of Features: 17
# Number of Instances: 804
# Histogram of Target Values:
# -----------------------------------
