# %%
# standard import
import pandas as pd
import numpy as np

# sklearn
from sklearn.ensemble import RandomForestRegressor
from sklearn.utils import resample
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans


# miscilaneous models
import openml
from ucimlrepo import fetch_ucirepo
import os

# import warnings
# warnings.simplefilter(action="ignore", category=FutureWarning)
# warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
X = pd.read_csv("../data/data_miami/X.csv")
y = pd.read_csv("../data/data_miami/y.csv", header=None).values.ravel()

# %%
# read in feature importances
base_dir = "../lfi-values/fulldata/rf/"
lotla_values = {}
shap_values = {}
lime_values = {}
women_count = {}
for seed in range(5):
    # split data into training and testing
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.5,
                                                        random_state = seed)
    lotla_values[seed] = np.loadtxt(base_dir + f"seed{seed}/parkinsons/elastic_nonnormed_nosquared_rank.csv", delimiter=",")
    shap_values[seed] = np.loadtxt(base_dir + f"seed{seed}/parkinsons/shap.csv", delimiter=",")
    lime_values[seed] = np.loadtxt(base_dir + f"seed{seed}/parkinsons/lime.csv", delimiter=",")

# %%
# plot heatmap of lotla values
import matplotlib.pyplot as plt
import seaborn as sns
for i in range(5):
    sns.set()
    plt.figure(figsize=(10, 5))
    sns.clustermap(lotla_values[i], cmap="viridis", cbar_kws={'label': 'Feature Importance'}, method="ward")
    plt.title("LMDI+ Clustermap")
    plt.xlabel("Features")
    plt.ylabel("")
    plt.show()

# %%
# plot heatmap of lotla values
import matplotlib.pyplot as plt
import seaborn as sns
for i in range(5):
    sns.set()
    plt.figure(figsize=(10, 5))
    sns.clustermap(shap_values[i], cmap="viridis", cbar_kws={'label': 'Feature Importance'}, method="ward")
    plt.title("SHAP Clustermap")
    plt.xlabel("Features")
    plt.ylabel("")
    plt.show()

# %%
# plot heatmap of lotla values
import matplotlib.pyplot as plt
import seaborn as sns
for i in range(5):
    sns.set()
    plt.figure(figsize=(10, 5))
    sns.clustermap(lime_values[i], cmap="viridis", cbar_kws={'label': 'Feature Importance'}, method="ward")
    plt.title("LIME Clustermap")
    plt.xlabel("Features")
    plt.ylabel("")
    plt.show()
