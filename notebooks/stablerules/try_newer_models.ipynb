# %%
# %load_ext autoreload
# %autoreload 2
import os
import pickle as pkl
from functools import partial
from os.path import join as oj

import numpy as np
import pandas as pd

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 50)
import sklearn as sk

import imodels
from imodels.util import data_util
from imodels.discretization import discretizer, simple

import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.rcParams['figure.dpi'] = 250

# change working directory to project root
while os.getcwd().split('/')[-1] != 'imodels-experiments':
    os.chdir('..')

import viz
# from experiments.util import get_comparison_result

np.random.seed(0)

# %%
X, y, feature_names = data_util.get_clean_dataset('compas_two_year_clean.csv', data_source='imodels')

# %%
eb_disc = discretizer.ExtraBasicDiscretizer(dcols=feature_names[:7], n_bins=2, strategy='uniform')

# %%
X_disc_df = eb_disc.fit_transform(pd.DataFrame(X, columns=feature_names))
X, feature_names = X_disc_df.values.astype(int), X_disc_df.columns.values
X_train, X_test, y_train, y_test = sk.model_selection.train_test_split(X, y, random_state=0)

# %% [markdown]
# ## try out corels

# %%
corels = imodels.OptimalRuleListClassifier(c=0.01, n_iter=100000)
corels.fit(X_train, y_train, feature_names=feature_names.tolist())

# %%
print(sk.metrics.accuracy_score(y_test, corels.predict(X_test)))
print(sk.metrics.roc_auc_score(y_test, corels.predict_proba(X_test)[:, 1]))
print(sk.metrics.average_precision_score(y_test, corels.predict_proba(X_test)[:, 1]))
# Out:
# 0.5910563836681789
# 0.5877727823802789
# 0.5295720756947329

# %%
corels.rl()
# Out:
# RULELIST:
# if [age_cat:25_-_45 && not race:African-American]:
#   prediction = False
# else if [sex:Male && not age_cat:Greater_than_45]:
#   prediction = True
# else
#   prediction = False
# All features: (['age_57.0_to_96.0', 'priors_count_19.0_to_38.0', 'days_b_screening_arrest_0.0_to_30.0', 'c_jail_time_399.0_to_799.0', 'juv_fel_count_10.0_to_20.0', 'juv_other_count_4.5_to_9.0', 'juv_misd_count_6.5_to_13.0', 'c_charge_degree:F', 'c_charge_degree:M', 'race:African-American', 'race:Asian', 'race:Caucasian', 'race:Hispanic', 'race:Native_American', 'race:Other', 'age_cat:25_-_45', 'age_cat:Greater_than_45', 'age_cat:Less_than_25', 'sex:Female', 'sex:Male'])

# %% [markdown]
# ## try out gosdt

# %%
# X, y, feature_names = data_util.get_clean_dataset('credit_card_clean.csv', data_source='imodels')
# dataframe = pd.DataFrame(np.concatenate((X, np.expand_dims(y, axis=1)), axis=1), columns=list(feature_names) + ['target'])

# X = dataframe.loc[:1000, dataframe.columns[:5]]
# y = dataframe.loc[:1000, dataframe.columns[-1:]]
# X_train, X_test, y_train, y_test = sk.model_selection.train_test_split(X, y, random_state=0)

# %%
gosdt = imodels.OptimalTreeClassifier(
    regularization=0.002,
    time_limit=30)

gosdt.fit(X_train, y_train)
print("Execution Time: {}".format(gosdt.time_))
# Out:
# Execution Time: 37.8120002746582

# %%
prediction = gosdt.predict(X_test)
# accuracy = sk.metrics.accuracy_score(y_test, prediction)
# print("Test Accuracy: {}".format(accuracy))
print(sk.metrics.accuracy_score(y_test, gosdt.predict(X_test)))
print(sk.metrics.roc_auc_score(y_test, gosdt.predict_proba(X_test)[:, 1]))
print(sk.metrics.average_precision_score(y_test, gosdt.predict_proba(X_test)[:, 1]))
print(gosdt.tree_)
# Out:
# 0.5962410887880751
# 0.44391964706674747
# 0.4797396596929082
# if X_0 = 1 and X_39 = 1 then:
#     predicted target: 0
#     misclassification penalty: 0.051
#     complexity penalty: 0.002
#
# else if X_0 = 1 and X_39 != 1 then:
#     predicted target: 1
#     misclassification penalty: 0.229
#     complexity penalty: 0.002
#
# else if X_0 != 1 and X_4 = 1 then:
#     predicted target: 0
#     misclassification penalty: 0.086
#     complexity penalty: 0.002
#
# else if X_0 != 1 and X_4 != 1 then:
#     predicted target: 1
#     misclassification penalty: 0.011
#     complexity penalty: 0.002

# %% [markdown]
# ## rulefit benchmark

# %%
rulefit = imodels.RuleFitClassifier(alpha=1, n_estimators=5, include_linear=False, random_state=0)
rulefit.fit(X_train, y_train, feature_names=feature_names)
# Out:
# /accounts/projects/binyu/keyan3/imodels/imodels/util/score.py:81: UserWarning: Ignoring max_rules parameter since alpha passed explicitly
#   warn("Ignoring max_rules parameter since alpha passed explicitly")
# RuleFitClassifier(alpha=1, include_linear=False, n_estimators=5, random_state=0)

# %%
print(sk.metrics.accuracy_score(y_test, rulefit.predict(X_test)))
print(sk.metrics.roc_auc_score(y_test, rulefit.predict_proba(X_test)[:, 1]))
print(sk.metrics.average_precision_score(y_test, rulefit.predict_proba(X_test)[:, 1]))
# Out:
# 0.5236552171095269
# 0.6032952785074427
# 0.5471815616200513

# %%
rulefit.get_rules()
# Out:
#                                                 rule  type      coef  \
# 0  age_18.0_to_37.5 <= 0.5 and priors_count_0.0_t...  rule -0.215274
# 1                            age_18.0_to_37.5 <= 0.5  rule -0.394429
# 2         age_18.0_to_37.5 > 0.5 and sex:Male <= 0.5  rule -0.169085
# 3  age_cat:Less_than_25 <= 0.5 and priors_count_0...  rule -0.363739
# 4  age_18.0_to_37.5 > 0.5 and priors_count_0.0_to...  rule -0.028657
# 5          age_18.0_to_37.5 > 0.5 and sex:Male > 0.5  rule  0.491793
# 6                     priors_count_0.0_to_9.5 <= 0.5  rule  1.288002
#
#     support  importance
# 0  0.080363    0.058523
# 1  0.319940    0.183983
# 2  0.127673    0.056428
# 3  0.691078    0.168065
# 4  0.623461    0.013885
# 5  0.552387    0.244543
# 6  0.093757    0.375440

# %% [markdown]
# ## BRS benchmark

# %%
brs = imodels.BoostedRulesClassifier(n_estimators=1, estimator=partial(sk.tree.DecisionTreeClassifier, max_depth=1))
brs.fit(X_train, y_train, feature_names=feature_names)
# Out:
# BoostedRulesClassifier(n_estimators=1)

# %%
brs.rules_
# Out:
# [race:African-American <= 0.5, race:African-American > 0.5]

# %%
a = {'ye': 1}
b = {'yes': 2, **a}

# %%
b
# Out:
# {'yes': 2, 'ye': 1}

# %%
for c, d in b.items():
    print(c, d)
# Out:
# yes 2
# ye 1

# %%
a.copy().pop('ye')
# Out:
# 1

# %%
a
# Out:
# {'ye': 1}

# %%
from collections import OrderedDict
import itertools

# %%
random_forest_grid = OrderedDict({
    'n_estimators': np.arange(1, 10),
    'max_samples': [0.8, 0.9, 1.0],
    'max_depth': [2, 3]
})

# %%
random_forest_grid
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_4181225/1830252893.py in <module>
# ----> 1 random_forest_grid.remove
#
# AttributeError: 'collections.OrderedDict' object has no attribute 'remove'

# %%
def grid_to_kwargs(grid: OrderedDict):
    all_kwargs = []

    for args_combo in itertools.product(*grid.values()):
        curr_kwargs = {list(grid.keys())[i]: args_combo[i] for i in range(len(grid))}
        all_kwargs.append(curr_kwargs)

    return all_kwargs

# %%
grid_to_kwargs(random_forest_grid)

# %%
# !python 01_run_comparisons.py --config rulevetting --dataset csi --splitting_strategy cv --model saps
# Out:
# dset csi ['csi']
# running datasets ['csi'] estimators [[saps, saps, saps, saps, saps, saps, saps, saps, saps, saps, saps, saps, saps, saps, saps, saps, saps, saps, saps, saps, saps, saps, saps, saps, saps, saps, saps, saps, saps]]
# saving to /accounts/projects/binyu/keyan3/imodels-experiments/results
#   0%|                                                     | 0/1 [00:00<?, ?it/s]	dataset csi ests [saps, saps, saps, saps, saps, saps, saps, saps, saps, saps, saps, saps, saps, saps, saps, saps, saps, saps, saps, saps, saps, saps, saps, saps, saps, saps, saps, saps, saps]
#
#   0%|                                                    | 0/29 [00:00<?, ?it/s]/accounts/projects/binyu/keyan3/miniconda3/envs/imodels-experiments-3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /accounts/projects/binyu/keyan3/miniconda3/envs/imodels-experiments-3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /accounts/projects/binyu/keyan3/miniconda3/envs/imodels-experiments-3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /accounts/projects/binyu/keyan3/miniconda3/envs/imodels-experiments-3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /accounts/projects/binyu/keyan3/miniconda3/envs/imodels-experiments-3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /accounts/projects/binyu/keyan3/miniconda3/envs/imodels-experiments-3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /accounts/projects/binyu/keyan3/miniconda3/envs/imodels-experiments-3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /accounts/projects/binyu/keyan3/miniconda3/envs/imodels-experiments-3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /accounts/projects/binyu/keyan3/miniconda3/envs/imodels-experiments-3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /accounts/projects/binyu/keyan3/miniconda3/envs/imodels-experiments-3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /accounts/projects/binyu/keyan3/miniconda3/envs/imodels-experiments-3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /accounts/projects/binyu/keyan3/miniconda3/envs/imodels-experiments-3.10/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#
#   3%|█▌                                          | 1/29 [00:00<00:13,  2.05it/s]
#   7%|███                                         | 2/29 [00:01<00:22,  1.20it/s]
#  10%|████▌                                       | 3/29 [00:03<00:33,  1.27s/it]
#  14%|██████                                      | 4/29 [00:06<00:46,  1.85s/it]
#  17%|███████▌                                    | 5/29 [00:09<01:00,  2.52s/it]
#  21%|█████████                                   | 6/29 [00:14<01:15,  3.27s/it]
#  24%|██████████▌                                 | 7/29 [00:20<01:29,  4.08s/it]
#  28%|████████████▏                               | 8/29 [00:27<01:43,  4.94s/it]
#  31%|█████████████▋                              | 9/29 [00:35<01:57,  5.89s/it]
#  34%|██████████████▊                            | 10/29 [00:44<02:12,  7.00s/it]
#  38%|████████████████▎                          | 11/29 [00:55<02:27,  8.19s/it]
#  41%|█████████████████▊                         | 12/29 [01:08<02:42,  9.54s/it]
#  45%|███████████████████▎                       | 13/29 [01:22<02:55, 10.95s/it]
#  48%|████████████████████▊                      | 14/29 [01:37<03:05, 12.40s/it]
#  52%|██████████████████████▏                    | 15/29 [01:55<03:14, 13.90s/it]
#  55%|███████████████████████▋                   | 16/29 [02:14<03:21, 15.47s/it]
#  59%|█████████████████████████▏                 | 17/29 [02:35<03:24, 17.05s/it]
#  62%|██████████████████████████▋                | 18/29 [02:57<03:25, 18.66s/it]
#  66%|████████████████████████████▏              | 19/29 [03:21<03:23, 20.32s/it]
#  69%|█████████████████████████████▋             | 20/29 [03:47<03:18, 22.01s/it]
#  72%|███████████████████████████████▏           | 21/29 [04:15<03:10, 23.81s/it]
#  76%|████████████████████████████████▌          | 22/29 [04:45<02:59, 25.61s/it]
#  79%|██████████████████████████████████         | 23/29 [05:17<02:44, 27.47s/it]
#  83%|███████████████████████████████████▌       | 24/29 [05:51<02:26, 29.39s/it]
#  86%|█████████████████████████████████████      | 25/29 [06:27<02:05, 31.33s/it]
#  90%|██████████████████████████████████████▌    | 26/29 [07:04<01:39, 33.22s/it]
#  93%|████████████████████████████████████████   | 27/29 [07:44<01:10, 35.13s/it]
#  97%|█████████████████████████████████████████▌ | 28/29 [08:25<00:37, 37.04s/it]
# 100%|███████████████████████████████████████████| 29/29 [09:09<00:00, 38.89s/it]
# 100%|████████████████████████████████████████████| 1/1 [09:09<00:00, 549.46s/it]
# completed all experiments successfully!

# %%
fname = oj('results', 'rulevetting', 'csi', 'cv/saps_comparisons.pkl')
saps_df = pkl.load(open(fname, 'rb'))['df']

# %%
saps_df.loc[:, ['train' in col for col in saps_df.columns]]
# Out:
#       csi_rocauc_train                                     csi_vars_train  \
# saps          0.660132  {'max_rules': 1, 'posthoc_ridge': False, 'incl...
# saps          0.700489  {'max_rules': 2, 'posthoc_ridge': False, 'incl...
# saps          0.742442  {'max_rules': 3, 'posthoc_ridge': False, 'incl...
# saps          0.750930  {'max_rules': 4, 'posthoc_ridge': False, 'incl...
# saps          0.775302  {'max_rules': 5, 'posthoc_ridge': False, 'incl...
# saps          0.783636  {'max_rules': 6, 'posthoc_ridge': False, 'incl...
# saps          0.786402  {'max_rules': 7, 'posthoc_ridge': False, 'incl...
# saps          0.793423  {'max_rules': 8, 'posthoc_ridge': False, 'incl...
# saps          0.794501  {'max_rules': 9, 'posthoc_ridge': False, 'incl...
# saps          0.820393  {'max_rules': 10, 'posthoc_ridge': False, 'inc...
# saps          0.827282  {'max_rules': 11, 'posthoc_ridge': False, 'inc...
# saps          0.843269  {'max_rules': 12, 'posthoc_ridge': False, 'inc...
# saps          0.849400  {'max_rules': 13, 'posthoc_ridge': False, 'inc...
# saps          0.851304  {'max_rules': 14, 'posthoc_ridge': False, 'inc...
# saps          0.852541  {'max_rules': 15, 'posthoc_ridge': False, 'inc...
# saps          0.857675  {'max_rules': 16, 'posthoc_ridge': False, 'inc...
# saps          0.861046  {'max_rules': 17, 'posthoc_ridge': False, 'inc...
# saps          0.868833  {'max_rules': 18, 'posthoc_ridge': False, 'inc...
# saps          0.872909  {'max_rules': 19, 'posthoc_ridge': False, 'inc...
# saps          0.881895  {'max_rules': 20, 'posthoc_ridge': False, 'inc...
# saps          0.882616  {'max_rules': 21, 'posthoc_ridge': False, 'inc...
# saps          0.885749  {'max_rules': 22, 'posthoc_ridge': False, 'inc...
# saps          0.889803  {'max_rules': 23, 'posthoc_ridge': False, 'inc...
# saps          0.891389  {'max_rules': 24, 'posthoc_ridge': False, 'inc...
# saps          0.897398  {'max_rules': 25, 'posthoc_ridge': False, 'inc...
# saps          0.898496  {'max_rules': 26, 'posthoc_ridge': False, 'inc...
# saps          0.899877  {'max_rules': 27, 'posthoc_ridge': False, 'inc...
# saps          0.899940  {'max_rules': 28, 'posthoc_ridge': False, 'inc...
# saps          0.903815  {'max_rules': 29, 'posthoc_ridge': False, 'inc...
#
#       csi_complexity_train  csi_time_train  csi_accuracy_train  csi_f1_train  \
# saps                     1        0.024599            0.835734      0.000000
# saps                     2        0.069160            0.851304      0.173160
# saps                     3        0.128966            0.864149      0.377897
# saps                     4        0.211567            0.866874      0.414384
# saps                     5        0.312551            0.866096      0.424749
# saps                     6        0.412265            0.866874      0.426174
# saps                     7        0.516771            0.873881      0.472313
# saps                     8        0.613601            0.877773      0.480132
# saps                     9        0.730142            0.880498      0.497545
# saps                    10        0.862041            0.876995      0.437722
# saps                    11        1.002572            0.878941      0.457243
# saps                    12        1.150200            0.882445      0.500000
# saps                    13        1.307256            0.882834      0.500829
# saps                    14        1.461918            0.883612      0.502496
# saps                    15        1.641018            0.887116      0.523026
# saps                    16        1.776672            0.887116      0.523026
# saps                    17        1.957423            0.892176      0.545156
# saps                    18        2.115429            0.895679      0.567742
# saps                    19        2.296310            0.899183      0.578862
# saps                    20        2.451654            0.906968      0.637329
# saps                    21        2.685737            0.904243      0.615625
# saps                    22        2.851078            0.907357      0.633846
# saps                    23        3.071349            0.908135      0.640244
# saps                    24        3.284795            0.909303      0.648567
# saps                    25        3.483923            0.909692      0.650602
# saps                    26        3.680653            0.906578      0.631902
# saps                    27        3.900011            0.911639      0.657617
# saps                    28        4.088845            0.911639      0.657617
# saps                    29        4.289966            0.914364      0.672619
#
#       csi_recall_train  csi_precision_train  csi_avg_precision_train  \
# saps          0.000000             0.000000                 0.284576
# saps          0.094787             1.000000                 0.372467
# saps          0.251185             0.762590                 0.445181
# saps          0.286730             0.746914                 0.469153
# saps          0.300948             0.721591                 0.499819
# saps          0.300948             0.729885                 0.512772
# saps          0.343602             0.755208                 0.541563
# saps          0.343602             0.796703                 0.558828
# saps          0.360190             0.804233                 0.571103
# saps          0.291469             0.878571                 0.602321
# saps          0.310427             0.867550                 0.618185
# saps          0.357820             0.829670                 0.635454
# saps          0.357820             0.834254                 0.641706
# saps          0.357820             0.843575                 0.646359
# saps          0.376777             0.854839                 0.655010
# saps          0.376777             0.854839                 0.659781
# saps          0.393365             0.887701                 0.678755
# saps          0.417062             0.888889                 0.689074
# saps          0.421801             0.922280                 0.709952
# saps          0.497630             0.886076                 0.725803
# saps          0.466825             0.903670                 0.727188
# saps          0.488152             0.903509                 0.732860
# saps          0.497630             0.897436                 0.742759
# saps          0.509479             0.892116                 0.745876
# saps          0.511848             0.892562                 0.751704
# saps          0.488152             0.895652                 0.755513
# saps          0.516588             0.904564                 0.765574
# saps          0.516588             0.904564                 0.766462
# saps          0.535545             0.904000                 0.771406
#
#       csi_best_accuracy_train  csi_best_spec_0.96_sens_train  \
# saps                 0.835734                       0.000000
# saps                 0.851304                       0.000000
# saps                 0.864149                       0.000000
# saps                 0.866874                       0.000000
# saps                 0.866096                       0.000000
# saps                 0.866874                       0.013973
# saps                 0.873881                       0.013973
# saps                 0.877773                       0.022823
# saps                 0.880498                       0.022823
# saps                 0.880498                       0.019562
# saps                 0.882445                       0.020494
# saps                 0.883223                       0.373079
# saps                 0.884391                       0.397764
# saps                 0.885169                       0.401025
# saps                 0.887116                       0.401025
# saps                 0.887894                       0.418724
# saps                 0.893344                       0.418724
# saps                 0.895679                       0.442478
# saps                 0.902686                       0.442478
# saps                 0.906968                       0.466698
# saps                 0.907357                       0.466698
# saps                 0.908135                       0.462972
# saps                 0.908135                       0.401490
# saps                 0.909303                       0.406614
# saps                 0.909692                       0.459711
# saps                 0.909692                       0.460643
# saps                 0.913974                       0.460643
# saps                 0.913974                       0.460643
# saps                 0.915142                       0.472753
#
#       csi_best_spec_0.98_sens_train
# saps                       0.000000
# saps                       0.000000
# saps                       0.000000
# saps                       0.000000
# saps                       0.000000
# saps                       0.013973
# saps                       0.013973
# saps                       0.022823
# saps                       0.022823
# saps                       0.019562
# saps                       0.020494
# saps                       0.010713
# saps                       0.024686
# saps                       0.026083
# saps                       0.026083
# saps                       0.031672
# saps                       0.031672
# saps                       0.055426
# saps                       0.055426
# saps                       0.078714
# saps                       0.078714
# saps                       0.078714
# saps                       0.072194
# saps                       0.074988
# saps                       0.076386
# saps                       0.076386
# saps                       0.076386
# saps                       0.076386
# saps                       0.081043

# %%
# fname = oj('results', 'saps', 'recidivism', 'train-test/Rulefit_comparisons.pkl')
# pkl.load(open(fname, 'rb'))['df']
