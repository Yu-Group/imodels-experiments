# %%
import numpy as np
import pickle as pkl
import matplotlib.pyplot as plt
import glob
import pandas as pd
import os
import matplotlib as mpl
from numpy import concatenate as cat
from collections import defaultdict
from sklearn import metrics
mpl.rcParams['figure.dpi'] = 250

# %%
results_tbi = pd.read_csv('results/tbi/tbi_final.csv').set_index('Unnamed: 0')
results_csi = pd.read_csv('results/csi/csi_final.csv').set_index('Unnamed: 0')

results_tbi_avg_metrics = results_tbi.iloc[:, -10:-5]
results_csi_avg_metrics = results_csi.iloc[:, -10:-5]

# %%
order = [0, 1, 5, 2, 4, 6]

# %% [markdown]
# ### tbi results

# %% [markdown]
# #### young

# %%
results_tbi_avg_metrics.filter(regex='.*_young', axis=0).iloc[order].style.highlight_max()
# Out:
# <style type="text/css">
# #T_7d03c_row3_col3, #T_7d03c_row4_col0, #T_7d03c_row4_col1, #T_7d03c_row4_col2, #T_7d03c_row5_col4 {
#   background-color: yellow;
# }
# </style>
# <table id="T_7d03c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >spec_0.94</th>
#       <th class="col_heading level0 col1" >spec_0.96</th>
#       <th class="col_heading level0 col2" >spec_0.98</th>
#       <th class="col_heading level0 col3" >auc</th>
#       <th class="col_heading level0 col4" >aps</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Unnamed: 0</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d03c_level0_row0" class="row_heading level0 row0" >cart_young</th>
# ...

# %% [markdown]
# #### old

# %%
results_tbi_avg_metrics[~results_tbi_avg_metrics.index.str.contains('young')].iloc[order].style.highlight_max()
# Out:
# <style type="text/css">
# #T_5c6c9_row1_col1, #T_5c6c9_row1_col3, #T_5c6c9_row4_col0, #T_5c6c9_row4_col2, #T_5c6c9_row5_col4 {
#   background-color: yellow;
# }
# </style>
# <table id="T_5c6c9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >spec_0.94</th>
#       <th class="col_heading level0 col1" >spec_0.96</th>
#       <th class="col_heading level0 col2" >spec_0.98</th>
#       <th class="col_heading level0 col3" >auc</th>
#       <th class="col_heading level0 col4" >aps</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Unnamed: 0</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c6c9_level0_row0" class="row_heading level0 row0" >cart</th>
# ...

# %% [markdown]
# ### csi results

# %%
results_csi_avg_metrics.filter(regex='.*_young', axis=0).iloc[order].style.highlight_max()
# Out:
# <style type="text/css">
# #T_15546_row4_col0, #T_15546_row4_col1, #T_15546_row4_col2, #T_15546_row4_col3, #T_15546_row4_col4 {
#   background-color: yellow;
# }
# </style>
# <table id="T_15546_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >spec_0.94</th>
#       <th class="col_heading level0 col1" >spec_0.96</th>
#       <th class="col_heading level0 col2" >spec_0.98</th>
#       <th class="col_heading level0 col3" >auc</th>
#       <th class="col_heading level0 col4" >aps</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Unnamed: 0</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15546_level0_row0" class="row_heading level0 row0" >cart_young</th>
# ...

# %%
results_csi_avg_metrics.filter(regex='.*_allage', axis=0).iloc[order].style.highlight_max()
# Out:
# <style type="text/css">
# #T_2fa7d_row1_col0, #T_2fa7d_row1_col4, #T_2fa7d_row3_col3, #T_2fa7d_row4_col1, #T_2fa7d_row4_col2 {
#   background-color: yellow;
# }
# </style>
# <table id="T_2fa7d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >spec_0.94</th>
#       <th class="col_heading level0 col1" >spec_0.96</th>
#       <th class="col_heading level0 col2" >spec_0.98</th>
#       <th class="col_heading level0 col3" >auc</th>
#       <th class="col_heading level0 col4" >aps</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Unnamed: 0</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2fa7d_level0_row0" class="row_heading level0 row0" >cart_allage</th>
# ...

# %%
results_csi_avg_metrics[
    ~results_csi_avg_metrics.index.str.contains('young') & 
    ~results_csi_avg_metrics.index.str.contains('allage')].iloc[order].style.highlight_max()
# Out:
# <style type="text/css">
# #T_09e1a_row1_col0, #T_09e1a_row2_col3, #T_09e1a_row4_col1, #T_09e1a_row4_col2, #T_09e1a_row4_col4 {
#   background-color: yellow;
# }
# </style>
# <table id="T_09e1a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >spec_0.94</th>
#       <th class="col_heading level0 col1" >spec_0.96</th>
#       <th class="col_heading level0 col2" >spec_0.98</th>
#       <th class="col_heading level0 col3" >auc</th>
#       <th class="col_heading level0 col4" >aps</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Unnamed: 0</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09e1a_level0_row0" class="row_heading level0 row0" >cart</th>
# ...
