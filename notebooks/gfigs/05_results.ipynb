# %%
import numpy as np
import pickle as pkl
import matplotlib.pyplot as plt
import glob
import pandas as pd
import os
import copy
import matplotlib as mpl
from numpy import concatenate as cat
from collections import defaultdict
from sklearn import metrics
mpl.rcParams['figure.dpi'] = 250
pd.set_option('precision', 3)
DATASET = 'iai'

# if 'tbi' in DATASET or 'csi' in DATASET:
seeds = sorted([
    int(path.split('_')[-1]) for path in glob.glob(f'results/{DATASET}/seed_*')])

if DATASET == 'sim':
    sens_levels = []
    METRICS = ['auc', 'aps', 'acc', 'f1']
else:
    sens_levels = [0.92, 0.94, 0.96, 0.98]
    METRICS = ['spec_0.92', 'spec_0.94', 'spec_0.96', 'spec_0.98', 'auc', 'aps', 'acc', 'f1']

# %%
# def plott(model_name, sens, spec, ppv, ax):
#     if 'pecarn' in model_name.lower():
#         # ax.plot(sens[0], spec[0], '.-', label=model_name)
#         pass
#     elif 'mix' not in model_name.lower() and 'pcart' not in model_name.lower():
#         ax.plot(sens, spec, '.-', label=model_name)

# %%
# def multiplot(paths, ax, suffix=""):
#     for model_file in paths:
#         basename = os.path.basename(model_file).split('.')[0]
#         dct = pkl.load(open(model_file, 'rb'))
#         plott(basename, dct['sens_tune'], dct['spec_tune'], dct['ppv_tune'], ax)
#     ax.legend(frameon=False, loc='best')
#     ax.set_xlim(0.9, 1)
    # ax.set_ylim(0, 0.2)

# %%
# def multiseedplot(group='all'):
#     fig, axes = plt.subplots(3, 3, figsize=(15, 15))
#     for k, seed in enumerate(seeds[:9]):
#         paths = sorted(glob.glob(f'results/{DATASET}/seed_{seed}/{group}/*.pkl'))
#         multiplot(paths, axes[k // 3, k % 3], group)
#     plt.xlabel('sens')
#     plt.ylabel('spec')
#     plt.tight_layout()

# %%
# multiseedplot()

# %%
# multiseedplot(group='young')

# %%
# multiseedplot(group='old')

# %%
def pkl_to_table(group):
    table = defaultdict(lambda:[])
    metrics_ = copy.copy(METRICS)
    if DATASET == 'iai' and group == 'young':
        metrics_.remove('auc')

    for i in seeds:

        seed_paths = sorted(glob.glob(f'results/{DATASET}/seed_{i}/{group}/*.pkl'))
        table_index = [os.path.basename(f).split('.')[0] for f in seed_paths]
        for model_file in seed_paths:
            dct = pkl.load(open(model_file, 'rb'))
            specs = np.array(dct['spec_tune'])
            senses = np.array(dct['sens_tune'])
            precisions = np.array(dct['ppv_tune'])
            for sens in sens_levels:
                table[f'spec_{sens}_seed_{i}'].append(
                    np.max(specs[senses > sens]) if specs[senses > sens].shape[0] > 0 else 0.0)
            if DATASET != 'iai' or group != 'young':
                table[f'auc_seed_{i}'].append(metrics.auc(1 - specs, senses))
            table[f'aps_seed_{i}'].append(-np.sum(np.diff(senses) * np.array(precisions)[:-1]))
            table[f'acc_seed_{i}'].append(dct['acc'])
            table[f'f1_seed_{i}'].append(dct['f1'])
        
    res_table = pd.DataFrame(table, index=table_index)
    if sens_levels:
        for i in seeds:
            res_table[f'high_spec_avg_seed_{i}'] = res_table.loc[
                :, [f'spec_0.92_seed_{i}', f'spec_0.94_seed_{i}', f'spec_0.96_seed_{i}', f'spec_0.98_seed_{i}']].mean(axis=1)

    for metric in metrics_:
        res_table_metric = res_table.loc[:, res_table.columns.str.contains(metric)]
        res_table[metric] = res_table_metric.mean(axis=1)

    # res_table['high_spec_avg'] = res_table[
    #     [f'spec_0.94', f'spec_0.96', f'spec_0.98']].mean(axis=1)

    for metric in metrics_:
        res_table_metric = res_table.loc[:, res_table.columns.str.contains(metric)]
        res_table[f'{metric}_std_err'] = res_table_metric.std(axis=1) / np.sqrt(10)
        # res_table[f'{metric}_std'] = res_table_metric.std(axis=1)
        
    return res_table

# %%
# pkl_to_table('all').to_csv(f'results/{DATASET}/all_average.csv')
# pkl_to_table('young').to_csv(f'results/{DATASET}/young_average.csv')
# pkl_to_table('old').to_csv(f'results/{DATASET}/old_average.csv')

# %%
pkl_to_table('all').iloc[:, -17:].style.background_gradient()#highlight_max(color='blue')
# Out:
# <style type="text/css">
# #T_4b6f3_row0_col0, #T_4b6f3_row1_col14, #T_4b6f3_row9_col4 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_4b6f3_row0_col1, #T_4b6f3_row7_col2, #T_4b6f3_row7_col14, #T_4b6f3_row12_col10 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_4b6f3_row0_col2, #T_4b6f3_row1_col15 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_4b6f3_row0_col3 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_4b6f3_row0_col4 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_4b6f3_row0_col5, #T_4b6f3_row1_col5, #T_4b6f3_row10_col14 {
#   background-color: #046097;
#   color: #f1f1f1;
# }
# #T_4b6f3_row0_col6, #T_4b6f3_row5_col9 {
#   background-color: #034e7b;
#   color: #f1f1f1;
# }
# #T_4b6f3_row0_col7, #T_4b6f3_row7_col7, #T_4b6f3_row13_col7 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_4b6f3_row0_col8 {
#   background-color: #03476f;
#   color: #f1f1f1;
# }
# #T_4b6f3_row0_col9 {
#   background-color: #1278b4;
#   color: #f1f1f1;
# }
# #T_4b6f3_row0_col10 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_4b6f3_row0_col11, #T_4b6f3_row4_col0, #T_4b6f3_row4_col3, #T_4b6f3_row6_col4, #T_4b6f3_row7_col15 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_4b6f3_row0_col12, #T_4b6f3_row1_col3, #T_4b6f3_row2_col0 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_4b6f3_row0_col13, #T_4b6f3_row3_col15, #T_4b6f3_row3_col16, #T_4b6f3_row5_col14, #T_4b6f3_row7_col5, #T_4b6f3_row7_col6, #T_4b6f3_row8_col0, #T_4b6f3_row8_col1, #T_4b6f3_row8_col2, #T_4b6f3_row8_col3, #T_4b6f3_row8_col4, #T_4b6f3_row8_col11, #T_4b6f3_row8_col12, #T_4b6f3_row9_col9, #T_4b6f3_row9_col10, #T_4b6f3_row11_col7, #T_4b6f3_row11_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_4b6f3_row0_col14, #T_4b6f3_row1_col9, #T_4b6f3_row2_col4, #T_4b6f3_row13_col11 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_4b6f3_row0_col15, #T_4b6f3_row5_col4, #T_4b6f3_row6_col12 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_4b6f3_row0_col16, #T_4b6f3_row10_col8 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_4b6f3_row1_col0, #T_4b6f3_row2_col15, #T_4b6f3_row12_col0 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_4b6f3_row1_col1 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_4b6f3_row1_col2, #T_4b6f3_row2_col11, #T_4b6f3_row4_col2, #T_4b6f3_row6_col10, #T_4b6f3_row12_col13 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_4b6f3_row1_col4, #T_4b6f3_row1_col12, #T_4b6f3_row3_col4, #T_4b6f3_row3_col12, #T_4b6f3_row8_col5, #T_4b6f3_row8_col6, #T_4b6f3_row8_col7, #T_4b6f3_row8_col8, #T_4b6f3_row8_col13, #T_4b6f3_row8_col14, #T_4b6f3_row8_col15, #T_4b6f3_row8_col16, #T_4b6f3_row11_col0, #T_4b6f3_row11_col1, #T_4b6f3_row11_col2, #T_4b6f3_row11_col3, #T_4b6f3_row11_col4, #T_4b6f3_row11_col9, #T_4b6f3_row11_col10, #T_4b6f3_row11_col11, #T_4b6f3_row11_col12, #T_4b6f3_row12_col4, #T_4b6f3_row12_col12 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_4b6f3_row1_col6 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# #T_4b6f3_row1_col7, #T_4b6f3_row12_col7, #T_4b6f3_row13_col6 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_4b6f3_row1_col8 {
#   background-color: #045585;
#   color: #f1f1f1;
# }
# #T_4b6f3_row1_col10, #T_4b6f3_row2_col1, #T_4b6f3_row7_col11 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_4b6f3_row1_col11 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_4b6f3_row1_col13 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_4b6f3_row1_col16 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_4b6f3_row2_col2, #T_4b6f3_row3_col11, #T_4b6f3_row6_col3, #T_4b6f3_row13_col3 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_4b6f3_row2_col3, #T_4b6f3_row11_col5 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_4b6f3_row2_col5, #T_4b6f3_row6_col7 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_4b6f3_row2_col6, #T_4b6f3_row9_col0 {
#   background-color: #023a5b;
#   color: #f1f1f1;
# }
# #T_4b6f3_row2_col7 {
#   background-color: #034267;
#   color: #f1f1f1;
# }
# #T_4b6f3_row2_col8, #T_4b6f3_row12_col8 {
#   background-color: #04598c;
#   color: #f1f1f1;
# }
# #T_4b6f3_row2_col9, #T_4b6f3_row7_col10 {
#   background-color: #2484ba;
#   color: #f1f1f1;
# }
# #T_4b6f3_row2_col10 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_4b6f3_row2_col12 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_4b6f3_row2_col13 {
#   background-color: #2383ba;
#   color: #f1f1f1;
# }
# #T_4b6f3_row2_col14, #T_4b6f3_row10_col2 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_4b6f3_row2_col16, #T_4b6f3_row4_col1, #T_4b6f3_row9_col2 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_4b6f3_row3_col0, #T_4b6f3_row10_col12 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_4b6f3_row3_col1, #T_4b6f3_row5_col10 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_4b6f3_row3_col2 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_4b6f3_row3_col3, #T_4b6f3_row7_col12, #T_4b6f3_row12_col14 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_4b6f3_row3_col5 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_4b6f3_row3_col6 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_4b6f3_row3_col7 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_4b6f3_row3_col8 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_4b6f3_row3_col9 {
#   background-color: #0569a4;
#   color: #f1f1f1;
# }
# #T_4b6f3_row3_col10 {
#   background-color: #045382;
#   color: #f1f1f1;
# }
# #T_4b6f3_row3_col13 {
#   background-color: #056fae;
#   color: #f1f1f1;
# }
# #T_4b6f3_row3_col14 {
#   background-color: #187cb6;
#   color: #f1f1f1;
# }
# #T_4b6f3_row4_col4, #T_4b6f3_row11_col15 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_4b6f3_row4_col5, #T_4b6f3_row5_col5, #T_4b6f3_row9_col14 {
#   background-color: #056dac;
#   color: #f1f1f1;
# }
# #T_4b6f3_row4_col6 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_4b6f3_row4_col7 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_4b6f3_row4_col8, #T_4b6f3_row5_col8 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_4b6f3_row4_col9, #T_4b6f3_row9_col6 {
#   background-color: #3b92c1;
#   color: #f1f1f1;
# }
# #T_4b6f3_row4_col10 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_4b6f3_row4_col11, #T_4b6f3_row12_col1 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_4b6f3_row4_col12, #T_4b6f3_row6_col9 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_4b6f3_row4_col13 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_4b6f3_row4_col14 {
#   background-color: #056aa6;
#   color: #f1f1f1;
# }
# #T_4b6f3_row4_col15, #T_4b6f3_row6_col0, #T_4b6f3_row6_col11, #T_4b6f3_row12_col11 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_4b6f3_row4_col16 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_4b6f3_row5_col0 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_4b6f3_row5_col1 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_4b6f3_row5_col2, #T_4b6f3_row6_col15 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_4b6f3_row5_col3, #T_4b6f3_row10_col4 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_4b6f3_row5_col6 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_4b6f3_row5_col7, #T_4b6f3_row9_col13 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_4b6f3_row5_col11 {
#   background-color: #4094c3;
#   color: #f1f1f1;
# }
# #T_4b6f3_row5_col12, #T_4b6f3_row12_col3 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_4b6f3_row5_col13 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_4b6f3_row5_col15 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_4b6f3_row5_col16, #T_4b6f3_row7_col3, #T_4b6f3_row12_col2 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_4b6f3_row6_col1, #T_4b6f3_row7_col13 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_4b6f3_row6_col2 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_4b6f3_row6_col5 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_4b6f3_row6_col6 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_4b6f3_row6_col8, #T_4b6f3_row9_col11 {
#   background-color: #046299;
#   color: #f1f1f1;
# }
# #T_4b6f3_row6_col13 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_4b6f3_row6_col14, #T_4b6f3_row9_col15 {
#   ba

# %%
s = '7'
pkl_to_table('all').iloc[[0, 1, 11, 12, 3, 4, 9], :].loc[:, [f'spec_0.92_seed_{s}', f'spec_0.94_seed_{s}', f'spec_0.96_seed_{s}', f'spec_0.98_seed_{s}']
    ].style.background_gradient()#highlight_max(color='blue')
# Out:
# <style type="text/css">
# #T_6e769_row0_col0, #T_6e769_row0_col1, #T_6e769_row0_col2, #T_6e769_row0_col3, #T_6e769_row1_col2, #T_6e769_row1_col3, #T_6e769_row2_col0, #T_6e769_row2_col1, #T_6e769_row2_col2, #T_6e769_row2_col3, #T_6e769_row3_col2, #T_6e769_row3_col3, #T_6e769_row4_col1, #T_6e769_row4_col2, #T_6e769_row4_col3, #T_6e769_row5_col2, #T_6e769_row5_col3, #T_6e769_row6_col0, #T_6e769_row6_col1, #T_6e769_row6_col2, #T_6e769_row6_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_6e769_row1_col0, #T_6e769_row3_col0 {
#   background-color: #023a5b;
#   color: #f1f1f1;
# }
# #T_6e769_row1_col1, #T_6e769_row3_col1, #T_6e769_row5_col0 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_6e769_row4_col0, #T_6e769_row5_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6e769_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >spec_0.92_seed_7</th>
#       <th class="col_heading level0 col1" >spec_0.94_seed_7</th>
#       <th class="col_heading level0 col2" >spec_0.96_seed_7</th>
#       <th class="col_heading level0 col3" >spec_0.98_seed_7</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e769_level0_row0" class="row_heading level0 row0" >cart_all</th>
#       <td id="T_6e769_row0_col0" class="data row0 col0" >0.000</td>
#       <td id="T_6e769_row0_col1" class="data row0 col1" >0.000</td>
#       <td id="T_6e769_row0_col2" class="data row0 col2" >0.000</td>
#       <td id="T_6e769_row0_col3" class="data row0 col3" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_6e769_level0_row1" class="row_heading level0 row1" >cart_combine</th>
#       <td id="T_6e769_row1_col0" class="data row1 col0" >0.096</td>
#       <td id="T_6e769_row1_col1" class="data row1 col1" >0.096</td>
#       <td id="T_6e769_row1_col2" class="data row1 col2" >0.000</td>
#       <td id="T_6e769_row1_col3" class="data row1 col3" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_6e769_level0_row2" class="row_heading level0 row2" >tao_all</th>
#       <td id="T_6e769_row2_col0" class="data row2 col0" >0.000</td>
#       <td id="T_6e769_row2_col1" class="data row2 col1" >0.000</td>
#       <td id="T_6e769_row2_col2" class="data row2 col2" >0.000</td>
#       <td id="T_6e769_row2_col3" class="data row2 col3" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_6e769_level0_row3" class="row_heading level0 row3" >tao_combine</th>
#       <td id="T_6e769_row3_col0" class="data row3 col0" >0.096</td>
#       <td id="T_6e769_row3_col1" class="data row3 col1" >0.096</td>
#       <td id="T_6e769_row3_col2" class="data row3 col2" >0.000</td>
#       <td id="T_6e769_row3_col3" class="data row3 col3" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_6e769_level0_row4" class="row_heading level0 row4" >figs_all</th>
#       <td id="T_6e769_row4_col0" class="data row4 col0" >0.097</td>
#       <td id="T_6e769_row4_col1" class="data row4 col1" >0.000</td>
#       <td id="T_6e769_row4_col2" class="data row4 col2" >0.000</td>
#       <td id="T_6e769_row4_col3" class="data row4 col3" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_6e769_level0_row5" class="row_heading level0 row5" >figs_combine</th>
#       <td id="T_6e769_row5_col0" class="data row5 col0" >0.096</td>
#       <td id="T_6e769_row5_col1" class="data row5 col1" >0.096</td>
#       <td id="T_6e769_row5_col2" class="data row5 col2" >0.000</td>
#       <td id="T_6e769_row5_col3" class="data row5 col3" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_6e769_level0_row6" class="row_heading level0 row6" >pfigs_combine</th>
#       <td id="T_6e769_row6_col0" class="data row6 col0" >0.000</td>
#       <td id="T_6e769_row6_col1" class="data row6 col1" >0.000</td>
#       <td id="T_6e769_row6_col2" class="data row6 col2" >0.000</td>
#       <td id="T_6e769_row6_col3" class="data row6 col3" >0.000</td>
#     </tr>
#   </tbody>
# </table>

# %%
pkl_to_table('young').iloc[:, -15:].drop('pecarn_young').style.background_gradient()#highlight_max(color='blue')
# Out:
# <style type="text/css">
# #T_bca59_row0_col0 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_bca59_row0_col1, #T_bca59_row0_col2, #T_bca59_row0_col3, #T_bca59_row0_col4 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_bca59_row0_col5 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_bca59_row0_col6 {
#   background-color: #0569a4;
#   color: #f1f1f1;
# }
# #T_bca59_row0_col7 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_bca59_row0_col8, #T_bca59_row0_col9, #T_bca59_row0_col10, #T_bca59_row0_col11 {
#   background-color: #045280;
#   color: #f1f1f1;
# }
# #T_bca59_row0_col12 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_bca59_row0_col13 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_bca59_row0_col14 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_bca59_row1_col0, #T_bca59_row1_col1, #T_bca59_row1_col2, #T_bca59_row1_col3, #T_bca59_row1_col4, #T_bca59_row1_col5, #T_bca59_row1_col8, #T_bca59_row1_col9, #T_bca59_row1_col10, #T_bca59_row1_col11, #T_bca59_row1_col12, #T_bca59_row1_col13, #T_bca59_row2_col6, #T_bca59_row2_col14, #T_bca59_row3_col0, #T_bca59_row4_col0, #T_bca59_row4_col7, #T_bca59_row6_col13, #T_bca59_row7_col0, #T_bca59_row7_col1, #T_bca59_row7_col2, #T_bca59_row7_col3, #T_bca59_row7_col4, #T_bca59_row7_col5, #T_bca59_row7_col8, #T_bca59_row7_col9, #T_bca59_row7_col10, #T_bca59_row7_col11, #T_bca59_row7_col12, #T_bca59_row7_col13 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_bca59_row1_col6, #T_bca59_row2_col1, #T_bca59_row2_col2, #T_bca59_row2_col3, #T_bca59_row2_col4, #T_bca59_row2_col8, #T_bca59_row2_col9, #T_bca59_row2_col10, #T_bca59_row2_col11, #T_bca59_row2_col12, #T_bca59_row2_col13, #T_bca59_row5_col0, #T_bca59_row5_col14, #T_bca59_row6_col5, #T_bca59_row6_col7, #T_bca59_row7_col6 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_bca59_row1_col7, #T_bca59_row3_col13, #T_bca59_row7_col7 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_bca59_row1_col14, #T_bca59_row7_col14 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_bca59_row2_col0 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_bca59_row2_col5 {
#   background-color: #03456c;
#   color: #f1f1f1;
# }
# #T_bca59_row2_col7 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_bca59_row3_col1, #T_bca59_row3_col2, #T_bca59_row3_col3, #T_bca59_row3_col4 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_bca59_row3_col5 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_bca59_row3_col6 {
#   background-color: #04588a;
#   color: #f1f1f1;
# }
# #T_bca59_row3_col7 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_bca59_row3_col8, #T_bca59_row3_col9, #T_bca59_row3_col10, #T_bca59_row3_col11 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_bca59_row3_col12, #T_bca59_row4_col13 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_bca59_row3_col14 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_bca59_row4_col1, #T_bca59_row4_col2, #T_bca59_row4_col3, #T_bca59_row4_col4 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_bca59_row4_col5 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_bca59_row4_col6 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_bca59_row4_col8, #T_bca59_row4_col9, #T_bca59_row4_col10, #T_bca59_row4_col11 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_bca59_row4_col12 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_bca59_row4_col14 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_bca59_row5_col1, #T_bca59_row5_col2, #T_bca59_row5_col3, #T_bca59_row5_col4 {
#   background-color: #3991c1;
#   color: #f1f1f1;
# }
# #T_bca59_row5_col5 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_bca59_row5_col6 {
#   background-color: #03476f;
#   color: #f1f1f1;
# }
# #T_bca59_row5_col7 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_bca59_row5_col8, #T_bca59_row5_col9, #T_bca59_row5_col10, #T_bca59_row5_col11 {
#   background-color: #0567a1;
#   color: #f1f1f1;
# }
# #T_bca59_row5_col12 {
#   background-color: #04629a;
#   color: #f1f1f1;
# }
# #T_bca59_row5_col13 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_bca59_row6_col0 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_bca59_row6_col1, #T_bca59_row6_col2, #T_bca59_row6_col3, #T_bca59_row6_col4 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_bca59_row6_col6 {
#   background-color: #045b8e;
#   color: #f1f1f1;
# }
# #T_bca59_row6_col8, #T_bca59_row6_col9, #T_bca59_row6_col10, #T_bca59_row6_col11 {
#   background-color: #045d92;
#   color: #f1f1f1;
# }
# #T_bca59_row6_col12 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_bca59_row6_col14 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# </style>
# <table id="T_bca59_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >high_spec_avg_seed_16</th>
#       <th class="col_heading level0 col1" >spec_0.92</th>
#       <th class="col_heading level0 col2" >spec_0.94</th>
#       <th class="col_heading level0 col3" >spec_0.96</th>
#       <th class="col_heading level0 col4" >spec_0.98</th>
#       <th class="col_heading level0 col5" >aps</th>
#       <th class="col_heading level0 col6" >acc</th>
#       <th class="col_heading level0 col7" >f1</th>
#       <th class="col_heading level0 col8" >spec_0.92_std_err</th>
#       <th class="col_heading level0 col9" >spec_0.94_std_err</th>
#       <th class="col_heading level0 col10" >spec_0.96_std_err</th>
#       <th class="col_heading level0 col11" >spec_0.98_std_err</th>
#       <th class="col_heading level0 col12" >aps_std_err</th>
#       <th class="col_heading level0 col13" >acc_std_err</th>
#       <th class="col_heading level0 col14" >f1_std_err</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bca59_level0_row0" class="row_heading level0 row0" >cart_all</th>
#       <td id="T_bca59_row0_col0" class="data row0 col0" >0.183</td>
#       <td id="T_bca59_row0_col1" class="data row0 col1" >0.296</td>
#       <td id="T_bca59_row0_col2" class="data row0 col2" >0.296</td>
#       <td id="T_bca59_row0_col3" class="data row0 col3" >0.296</td>
#       <td id="T_bca59_row0_col4" class="data row0 col4" >0.296</td>
#       <td id="T_bca59_row0_col5" class="data row0 col5" >0.044</td>
#       <td id="T_bca59_row0_col6" class="data row0 col6" >0.821</td>
#       <td id="T_bca59_row0_col7" class="data row0 col7" >0.059</td>
#       <td id="T_bca59_row0_col8" class="data row0 col8" >0.097</td>
#       <td id="T_bca59_row0_col9" class="data row0 col9" >0.097</td>
#       <td id="T_bca59_row0_col10" class="data row0 col10" >0.097</td>
#       <td id="T_bca59_row0_col11" class="data row0 col11" >0.097</td>
#       <td id="T_bca59_row0_col12" class="data row0 col12" >0.007</td>
#       <td id="T_bca59_row0_col13" class="data row0 col13" >0.011</td>
#       <td id="T_bca59_row0_col14" class="data row0 col14" >0.010</td>
#     </tr>
#     <tr>
#       <th id="T_bca59_level0_row1" class="row_heading level0 row1" >cart_young</th>
#       <td id="T_bca59_row1_col0" class="data row1 col0" >0.000</td>
#       <td id="T_bca59_row1_col1" class="data row1 col1" >0.000</td>
#       <td id="T_bca59_row1_col2" class="data row1 col2" >0.000</td>
#       <td id="T_bca59_row1_col3" class="data row1 col3" >0.000</td>
#       <td id="T_bca59_row1_col4" class="data row1 col4" >0.000</td>
#       <td id="T_bca59_row1_col5" class="data row1 col5" >0.007</td>
#       <td id="T_bca59_row1_col6" class="data row1 col6" >0.886</td>
#       <td id="T_bca59_row1_col7" class="data row1 col7" >0.025</td>
#       <td id="T_bca59_row1_col8" class="data row1 col8" >0.000</td>
#       <td id="T_bca59_row1_col9" class="data row1 col9" >0.000</td>
#       <td id="T_bca59_row1_col10" class="data row1 col10" >0.000</td>
#       <td id="T_bca59_row1_col11" class="data row1 col11" >0.000</td>
#       <td id="T_bca59_row1_col12" class="data row1 col12" >0.003</td>
#       <td id="T_bca59_row1_col13" class="data row1 col13" >0.007</td>
#       <td id="T_bca59_row1_col14" class="data row1 col14" >0.010</td>
#     </tr>
#     <tr>
#       <th id="T_bca59_level0_row2" class="row_heading level0 row2" >figs_all</th>
#       <td id="T_bca59_row2_col0" class="data row2 c

# %%
pkl_to_table('old').iloc[:, -15:].drop('pecarn_old').style.background_gradient()#highlight_max(color='blue')
# Out:
# <style type="text/css">
# #T_f8df4_row0_col0, #T_f8df4_row0_col1 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_f8df4_row0_col2 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# #T_f8df4_row0_col3 {
#   background-color: #023b5d;
#   color: #f1f1f1;
# }
# #T_f8df4_row0_col4, #T_f8df4_row1_col6 {
#   background-color: #045e94;
#   color: #f1f1f1;
# }
# #T_f8df4_row0_col5 {
#   background-color: #03456c;
#   color: #f1f1f1;
# }
# #T_f8df4_row0_col6 {
#   background-color: #034871;
#   color: #f1f1f1;
# }
# #T_f8df4_row0_col7 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_f8df4_row0_col8 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_f8df4_row0_col9 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_f8df4_row0_col10 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_f8df4_row0_col11 {
#   background-color: #3991c1;
#   color: #f1f1f1;
# }
# #T_f8df4_row0_col12 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_f8df4_row0_col13, #T_f8df4_row2_col2, #T_f8df4_row2_col10, #T_f8df4_row3_col4, #T_f8df4_row3_col5, #T_f8df4_row3_col6, #T_f8df4_row3_col14, #T_f8df4_row5_col11, #T_f8df4_row6_col0, #T_f8df4_row6_col1, #T_f8df4_row6_col2, #T_f8df4_row6_col3, #T_f8df4_row6_col7, #T_f8df4_row6_col8, #T_f8df4_row6_col9, #T_f8df4_row6_col10, #T_f8df4_row6_col12 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_f8df4_row0_col14, #T_f8df4_row3_col13 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_f8df4_row1_col0 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_f8df4_row1_col1, #T_f8df4_row7_col1 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_f8df4_row1_col2, #T_f8df4_row7_col2 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_f8df4_row1_col3, #T_f8df4_row4_col5 {
#   background-color: #04649e;
#   color: #f1f1f1;
# }
# #T_f8df4_row1_col4, #T_f8df4_row7_col3 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_f8df4_row1_col5, #T_f8df4_row2_col8, #T_f8df4_row3_col7, #T_f8df4_row7_col4, #T_f8df4_row7_col5 {
#   background-color: #034f7d;
#   color: #f1f1f1;
# }
# #T_f8df4_row1_col7 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
# }
# #T_f8df4_row1_col8 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_f8df4_row1_col9, #T_f8df4_row3_col2, #T_f8df4_row7_col9 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_f8df4_row1_col10, #T_f8df4_row7_col10 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_f8df4_row1_col11 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_f8df4_row1_col12 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_f8df4_row1_col13 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_f8df4_row1_col14 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_f8df4_row2_col0 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_f8df4_row2_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_f8df4_row2_col3 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_f8df4_row2_col4 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_f8df4_row2_col5 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_f8df4_row2_col6, #T_f8df4_row2_col11 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_f8df4_row2_col7 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_f8df4_row2_col9 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_f8df4_row2_col12 {
#   background-color: #2c89bd;
#   color: #f1f1f1;
# }
# #T_f8df4_row2_col13, #T_f8df4_row2_col14, #T_f8df4_row3_col12, #T_f8df4_row4_col4, #T_f8df4_row4_col11, #T_f8df4_row5_col0, #T_f8df4_row5_col1, #T_f8df4_row5_col2, #T_f8df4_row5_col3, #T_f8df4_row5_col7, #T_f8df4_row5_col8, #T_f8df4_row5_col9, #T_f8df4_row5_col10, #T_f8df4_row6_col5, #T_f8df4_row6_col6 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_f8df4_row3_col0 {
#   background-color: #045c90;
#   color: #f1f1f1;
# }
# #T_f8df4_row3_col1 {
#   background-color: #2484ba;
#   color: #f1f1f1;
# }
# #T_f8df4_row3_col3, #T_f8df4_row5_col12 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_f8df4_row3_col8 {
#   background-color: #04588a;
#   color: #f1f1f1;
# }
# #T_f8df4_row3_col9 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_f8df4_row3_col10 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_f8df4_row3_col11 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_f8df4_row4_col0 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_f8df4_row4_col1, #T_f8df4_row4_col2 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_f8df4_row4_col3 {
#   background-color: #0566a0;
#   color: #f1f1f1;
# }
# #T_f8df4_row4_col6 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_f8df4_row4_col7 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_f8df4_row4_col8, #T_f8df4_row7_col7 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_f8df4_row4_col9 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_f8df4_row4_col10 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_f8df4_row4_col12 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_f8df4_row4_col13 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_f8df4_row4_col14 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_f8df4_row5_col4 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_f8df4_row5_col5 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_f8df4_row5_col6, #T_f8df4_row7_col8 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_f8df4_row5_col13 {
#   background-color: #2f8bbe;
#   color: #f1f1f1;
# }
# #T_f8df4_row5_col14 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_f8df4_row6_col4 {
#   background-color: #056caa;
#   color: #f1f1f1;
# }
# #T_f8df4_row6_col11 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_f8df4_row6_col13 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_f8df4_row6_col14 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_f8df4_row7_col0 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_f8df4_row7_col6 {
#   background-color: #046299;
#   color: #f1f1f1;
# }
# #T_f8df4_row7_col11 {
#   background-color: #549cc7;
#   color: #f1f1f1;
# }
# #T_f8df4_row7_col12 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_f8df4_row7_col13 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_f8df4_row7_col14 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# </style>
# <table id="T_f8df4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >spec_0.94</th>
#       <th class="col_heading level0 col1" >spec_0.96</th>
#       <th class="col_heading level0 col2" >spec_0.98</th>
#       <th class="col_heading level0 col3" >auc</th>
#       <th class="col_heading level0 col4" >aps</th>
#       <th class="col_heading level0 col5" >acc</th>
#       <th class="col_heading level0 col6" >f1</th>
#       <th class="col_heading level0 col7" >spec_0.92_std_err</th>
#       <th class="col_heading level0 col8" >spec_0.94_std_err</th>
#       <th class="col_heading level0 col9" >spec_0.96_std_err</th>
#       <th class="col_heading level0 col10" >spec_0.98_std_err</th>
#       <th class="col_heading level0 col11" >auc_std_err</th>
#       <th class="col_heading level0 col12" >aps_std_err</th>
#       <th class="col_heading level0 col13" >acc_std_err</th>
#       <th class="col_heading level0 col14" >f1_std_err</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8df4_level0_row0" class="row_heading level0 row0" >cart_all</th>
#       <td id="T_f8df4_row0_col0" class="data row0 col0" >0.028</td>
#       <td id="T_f8df4_row0_col1" class="data row0 col1" >0.016</td>
#       <td id="T_f8df4_row0_col2" class="data row0 col2" >0.013</td>
#       <td id="T_f8df4_row0_col3" class="data row0 col3" >0.691</td>
#       <td id="T_f8df4_row0_col4" class="data row0 col4" >0.086</td>
#       <td id="T_f8df4_row0_col5" class="data row0 col5" >0.834</td>
#       <td id="T_f8df4_row0_col6" class="data row0 col6" >0.142</td>
#       <td id="T_f8df4_row0_col7" class="data row0 col7" >0.039</td>
#       <td id="T_f8df4_row0_col8" class="data row0 col8" >0.011</td>
#       <td id="T_f8df4_row0_col9" class="data row0 col9" >0.005</td>
#       <td id="T_f8df4_row0_col10" class="data row0 col10" >0.005</td>
#       <td id="T_f8df4_row0_col11" class="data row0 col11" >0.057</td>
#       <td id="T_f8df4_row0_col12" class="data row0 col12" >0.
