# %%
import pandas as pd
import numpy as np
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.inspection import permutation_importance
import statsmodels.api as sm
from scipy import stats
import sys
import shap
import methods
from methods import lin_reg_t_test, tree_mdi, perm_importance, knockpy_swap_integral, tree_shap_mean

# %%
diabetes = datasets.load_diabetes()
X = diabetes.data
y = diabetes.target

# %%
#X = pd.DataFrame(data=X, columns=['X1','X2','X3','X4','X5','X6','X7','X8','X9','X10'])
lin_reg = sm.OLS(y, X)
lin_reg_fit = lin_reg.fit()
print(lin_reg_fit.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.106
# Model:                            OLS   Adj. R-squared (uncentered):              0.085
# Method:                 Least Squares   F-statistic:                              5.100
# Date:                Thu, 24 Feb 2022   Prob (F-statistic):                    4.72e-07
# Time:                        09:30:50   Log-Likelihood:                         -2873.9
# No. Observations:                 442   AIC:                                      5768.
# Df Residuals:                     432   BIC:                                      5809.
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
results = lin_reg_t_test(X,y,lin_reg_fit)
results
# Out:
#    Var  Importance
# 0    0    0.955659
# 1    1    0.194119
# 2    2    0.009809
# 3    3    0.100448
# 4    4    0.528251
# 5    5    0.640838
# 6    6    0.874654
# 7    7    0.715997
# 8    8    0.147512
# 9    9    0.733827

# %%
decision_tree = DecisionTreeRegressor(random_state=0)
decision_tree_fit = decision_tree.fit(X, y)

random_forest = RandomForestClassifier(random_state=0)
random_forest_fit = random_forest.fit(X, y)

# %%
results = tree_mdi(X,y,decision_tree_fit)
results
# Out:
#    Var  Importance
# 0    0    0.046088
# 1    1    0.009412
# 2    2    0.233386
# 3    3    0.075490
# 4    4    0.069857
# 5    5    0.069513
# 6    6    0.071462
# 7    7    0.013112
# 8    8    0.347962
# 9    9    0.063718

# %%
results = tree_mdi(X,y,random_forest_fit)
results
# Out:
#    Var  Importance
# 0    0    0.108655
# 1    1    0.026756
# 2    2    0.123988
# 3    3    0.111157
# 4    4    0.111698
# 5    5    0.117195
# 6    6    0.110542
# 7    7    0.061189
# 8    8    0.119919
# 9    9    0.108900

# %%
results = perm_importance(X,y,decision_tree_fit)
results
# Out:
#    Var  Importance
# 0    0    0.142999
# 1    1    0.135123
# 2    2    1.022482
# 3    3    0.414241
# 4    4    0.253593
# 5    5    0.261534
# 6    6    0.330689
# 7    7    0.032236
# 8    8    0.906423
# 9    9    0.242232

# %%
results = knockpy_swap_integral(X,y,decision_tree)
results
# Out:
# 	---------------------------------------------------------
# 	---------------------------------------------------------
# 	The choldate package is not installed:
# 	solving for MVR or maxent knockoffs without it will be
# 	~5x slower. For instructions on how to install choldate,
# 	see https://amspector100.github.io/knockpy/installation.html.
# 	To disable this warning, set choldate_warning=False as an
# 	argument or a knockoff_kwarg.
# 	----------------------------------------------------------
# 	----------------------------------------------------------
#
# Treating y data as continuous even though it may be discrete.
#    Var  Rejected
# 0    0       0.0
# 1    1       0.0
# 2    2       0.0
# 3    3       0.0
# 4    4       0.0
# 5    5       0.0
# 6    6       0.0
# 7    7       0.0
# 8    8       0.0
# 9    9       0.0

# %%
X, y = shap.datasets.boston()
results = tree_shap_mean(X,y,decision_tree_fit)
